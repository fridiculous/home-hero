# %%
import pandas as pd
# %matplotlib inline

# %%
import json

# %%
data = open('../../data/pub_transactions.json', 'r')
d = json.load(data)

# %%
df = pd.DataFrame([i for i in d['bundle']])

# %%
df.T
# Out:
#                                                                                 0  \
# borrowerVesting                                                              None
# buyerMultiVesting
# buyerName                                                                    None
# buyerVesting
# cityTransferTax                                                              None
# county                                                                      DODGE
# countyTransferTax                                                            None
# documentDate                                             2015-04-28T00:00:00.000Z
# documentType                                               Deed of Trust/Mortgage
# documentTypeCode                                                             MTGE
# effectiveDate                                                                None
# fips                                                                        55027
# ...

# %%
df.head().T
# Out:
#                                                                                 0  \
# borrowerVesting                                                              None
# buyerMultiVesting
# buyerName                                                                    None
# buyerVesting
# cityTransferTax                                                              None
# county                                                                      DODGE
# countyTransferTax                                                            None
# documentDate                                             2015-04-28T00:00:00.000Z
# documentType                                               Deed of Trust/Mortgage
# documentTypeCode                                                             MTGE
# effectiveDate                                                                None
# fips                                                                        55027
# ...
